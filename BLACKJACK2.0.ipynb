# %%
from random import shuffle
PLAYING = True

SUITS = ('Hearts', 'Diamonds', 'Spades', 'Clubs')
RANKS = ('Two', 'Three', 'Four', 'Five', 'Six', 'Seven', 'Eight', 'Nine', 'Ten', 'Jack', 'Queen', 'King', 'Ace')
VALUES = {'Two':2, 'Three':3, 'Four':4, 'Five':5, 'Six':6, 'Seven':7, 'Eight':8, 'Nine':9, 'Ten':10, 'Jack':10,
        'Queen':10, 'King':10, 'Ace':11}

class Card:
    def __init__(self,suit,rank):
        self.suit = suit
        self.rank = rank
        self.value = VALUES[self.rank]
        
    def __str__(self):
        return self.rank + " of " + self.suit
    
    

class Deck:
    def  __init__(self):
        self.cards = []
        for suit in SUITS:
            for rank in RANKS:
                self.cards.append(Card(suit,rank))
                
    def deckShuffle(self):
        shuffle(self.cards)
                
    def dealOne(self):
        newCard = self.cards.pop()
        return newCard
    
        
class Hand:
    def __init__(self):
        self.cards = []
        self.value = 0
        self.aces = 0
        
    def addCard(self,card):
        self.cards.append(card)
        self.value += card.value
        if card.rank == "Ace":
            self.aces += 1
        
        
    def adjustAce(self):
        if self.value > 21 and self.aces > 0:
            self.value -= 10
            self.aces -= 1
            
class Chip:
    
    def __init__(self):
        self.total = 100
        self.bet = 0
        
        
    def winBet(self):
        self.total += self.bet
        
    def loseBet(self):
        self.total -= self.bet

def takeBet(chip):
    
    while True:
        try:
            chip.bet = int(input("Enter the bet amount: "))
        except:
            print("Please enter a valid a integer amount: ")
        else:
            if chip.bet > chip.total:
                print(f"You bet amount cannot be greater than you total amount i.e {chip.total}")
                continue
            else:
                print("BET ACCEPTED!\n")
                break
                
        
def showSomeCards(player, dealer):
    print("----PLAYER'S CARDS---- ")
    print(*player.cards, sep="\n")
    print()
   
    print("----DEALER'S CARDS---- ")
    print("<Card Hidden>")
    print(dealer.cards[1])
    

def showAllCards(player, dealer):
    print("----PLAYER'S CARD---- ")
    print(*player.cards, sep="\n")
    print()
    print("----DEALER CARD'S---- ")
    print(*dealer.cards, sep = "\n")


def hit(hand,deck):
    hand.addCard(deck.dealOne())
    hand.adjustAce()
    
def hitOrStand(hand,deck):
    global PLAYING
    
    while True:
        choice = input("Do you want to hit or stand? 'h' for HIT and 's' for STAND: ")
        
        if choice == "h":
            hit(hand,deck)
            
            
        elif choice == "s":
            PLAYING = False
            
        else:
            print("Your choice is not valid! ")
            continue
            
        break
            

def playerWins(chips):
    print("Player wins ")
    chips.winBet()
    
def playerBusts(chips):
    print("Player busted!")
    chips.loseBet()
    
def dealerWins(chips):
    print("Dealer wins")
    chips.loseBet()
    
def dealerBust(chips):
    print("Dealer Busted")
    chips.winBet()
    
def tie():
    print("Its a DRAW!")
            
            
    
    
    
    

while True:
    print("WELCOME TO BLACK JACK GAME!!!! \n \n \n")
    deck = Deck()
    deck.deckShuffle()
    
    playerHand = Hand()
    playerHand.addCard(deck.dealOne())
    playerHand.addCard(deck.dealOne())
    
    dealerHand = Hand()
    dealerHand.addCard(deck.dealOne())
    dealerHand.addCard(deck.dealOne())
    
    playerChips = Chip()
    takeBet(playerChips)
    
    showSomeCards(playerHand, dealerHand)
    
    while PLAYING:
        hitOrStand(playerHand, deck)
        if playerHand.value > 21:
            playerBusts(playerChips)
            break
    
    if playerHand.value <= 21:
        while dealerHand.value < 17:
            hit(dealerHand,deck)
            
        showAllCards(playerHand,dealerHand)
            
        if dealerHand.value > 21:
            dealerBusts(playerChips)
            
        elif playerHand.value > dealerHand.value:
            playerWins(playerChips)
            
        elif playerHand.value < dealerHand.value:
            dealerWins(playerChips)
        else:
            tie()
            
    gameOn = input("Do you want to play again - yes/no? ")
    if gameOn == "no":
        print("\n THANKS FOR PLAYING!!!")
        break
    else:
        PLAYING = True
# Out:
# WELCOME TO BLACK JACK GAME!!!!
#
#
#
# Enter the bet amount: 25
# BET ACCEPTED!
#
# ----PLAYER'S CARDS----
# Eight of Diamonds
# Five of Hearts
#
# ----DEALER'S CARDS----
# <Card Hidden>
# Ten of Hearts
# Do you want to hit or stand? 'h' for HIT and 's' for STAND: s
# ----PLAYER'S CARD----
# Eight of Diamonds
# Five of Hearts
#
# ----DEALER CARD'S----
# Jack of Hearts
# Ten of Hearts
# Dealer wins
# Do you want to play again - yes/no? yes
# WELCOME TO BLACK JACK GAME!!!!
#
#
#
# Enter the bet amount: 25
# BET ACCEPTED!
#
# ----PLAYER'S CARDS----
# Four of Spades
# Ten of Clubs
#
# ----DEALER'S CARDS----
# <Card Hidden>
# King of Hearts
# Do you want to hit or stand? 'h' for HIT and 's' for STAND: h
# Do you want to hit or stand? 'h' for HIT and 's' for STAND: s
# ----PLAYER'S CARD----
# Four of Spades
# Ten of Clubs
# Ace of Hearts
#
# ----DEALER CARD'S----
# Seven of Clubs
# King of Hearts
# Dealer wins
# Do you want to play again - yes/no? yes
# WELCOME TO BLACK JACK GAME!!!!
#
#
# ...
